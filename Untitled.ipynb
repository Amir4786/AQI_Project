# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv("AQI.csv")

# %%
df=df.iloc[:-2,1:]
df
# Out:
#      PM2.5   PM10    NO2   NH3   SO2    CO  OZONE  AQI (avg. of past 24hrs)
# 0    446.0  393.0   73.0  12.0  21.0  88.0   75.0                      437.0
# 1    431.0  382.0   71.0  13.0  28.0  87.0   64.0                      417.0
# 2    361.0  324.0   61.0  11.0  22.0  70.0   58.0                      352.0
# 3    342.0  302.0   63.0  12.0  17.0  70.0   58.0                      334.0
# 4    339.0  262.0   55.0  11.0  13.0  50.0   63.0                      330.0
# ..     ...    ...    ...   ...   ...   ...    ...                        ...
# 361  405.0  363.0  110.0  15.0  19.0  92.0   52.0                      396.0
# 362  254.0  247.0   83.0  11.0  16.0  53.0   43.0                      253.0
# 363  249.0  234.0   89.0  11.0  15.0  62.0   43.0                      265.0
# 364  316.0  229.0   85.0  13.0  11.0  68.0   29.0                      290.0
# 365  342.0  217.0   87.0  13.0  11.0  76.0   24.0                      347.0
#
# [366 rows x 8 columns]

# %%
df.isnull().sum()
# Out:
# PM2.5                        0
# PM10                         0
# NO2                          0
# NH3                          0
# SO2                          0
# CO                           0
# OZONE                        0
# AQI (avg. of past 24hrs)     0
# dtype: int64

# %%
df.columns
# Out:
# Index(['PM2.5', 'PM10', 'NO2', 'NH3', 'SO2', 'CO', 'OZONE',
#        'AQI (avg. of past 24hrs) '],
#       dtype='object')

# %%
df.corr()
# Out:
#                               PM2.5      PM10       NO2       NH3       SO2  \
# PM2.5                      1.000000  0.947647  0.785896  0.762192  0.530802
# PM10                       0.947647  1.000000  0.832622  0.774835  0.553524
# NO2                        0.785896  0.832622  1.000000  0.680698  0.474660
# NH3                        0.762192  0.774835  0.680698  1.000000  0.356114
# SO2                        0.530802  0.553524  0.474660  0.356114  1.000000
# CO                         0.772109  0.791925  0.752379  0.723579  0.350161
# OZONE                      0.303648  0.387140  0.471165  0.289998  0.481700
# AQI (avg. of past 24hrs)   0.978072  0.959698  0.802867  0.763115  0.490488
#
#                                  CO     OZONE  AQI (avg. of past 24hrs)
# PM2.5                      0.772109  0.303648                   0.978072
# PM10                       0.791925  0.387140                   0.959698
# ...

# %%
sns.pairplot(df)

# %%
#independent and dependent features
x= df.iloc[:,:-1]
y= df.iloc[:,-1]

# %%
y
# Out:
# 0      437.0
# 1      417.0
# 2      352.0
# 3      334.0
# 4      330.0
#        ...
# 361    396.0
# 362    253.0
# 363    265.0
# 364    290.0
# 365    347.0
# Name: AQI (avg. of past 24hrs) , Length: 366, dtype: float64

# %%
#feature importance
from sklearn.ensemble import ExtraTreesRegressor
model= ExtraTreesRegressor()
model.fit(x,y)
# Out:
# ExtraTreesRegressor()

# %%
model.feature_importances_
# Out:
# array([0.52830967, 0.33944958, 0.05109909, 0.01314431, 0.00304745,
#        0.06011827, 0.00483162])

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test= train_test_split(x,y,test_size=0.2)

# %%
X_train.shape
# Out:
# (292, 7)

# %%
X_test.shape
# Out:
# (74, 7)

# %%
y_test.shape
# Out:
# (74,)

# %%
from sklearn.ensemble import RandomForestRegressor
rf_regressor= RandomForestRegressor()

# %%
# Hyperparameters
n_estimators= [int(x) for x in np.linspace(start=100, stop=1200, num=12)]
max_features=["auto","sqrt"]
max_depth= [int(x) for x in np.linspace(start=5, stop=100, num=6)]
min_sample_split= [2,5,10,15,100]
min_sample_leaf= [2,5,9,12,15,20]
print(n_estimators)
# Out:
# [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200]

# %%
from sklearn.model_selection import RandomizedSearchCV
random_grid= {'n_estimators':n_estimators,'max_features':max_features,'max_depth':max_depth,'min_samples_split':min_sample_split,'min_samples_leaf':min_sample_leaf}

# %%
rf= RandomForestRegressor()
rf_random= RandomizedSearchCV(estimator=rf,param_distributions=random_grid,scoring='neg_mean_squared_error',n_iter=10, cv=5, verbose=2, random_state=42)

# %%
rf_random.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] END max_depth=24, max_features=auto, min_samples_leaf=9, min_samples_split=5, n_estimators=900; total time=   1.4s
# [CV] END max_depth=24, max_features=auto, min_samples_leaf=9, min_samples_split=5, n_estimators=900; total time=   1.3s
# [CV] END max_depth=24, max_features=auto, min_samples_leaf=9, min_samples_split=5, n_estimators=900; total time=   1.3s
# [CV] END max_depth=24, max_features=auto, min_samples_leaf=9, min_samples_split=5, n_estimators=900; total time=   1.5s
# [CV] END max_depth=24, max_features=auto, min_samples_leaf=9, min_samples_split=5, n_estimators=900; total time=   1.4s
# [CV] END max_depth=100, max_features=auto, min_samples_leaf=9, min_samples_split=100, n_estimators=500; total time=   0.6s
# [CV] END max_depth=100, max_features=auto, min_samples_leaf=9, min_samples_split=100, n_estimators=500; total time=   0.6s
# ...

# %%
rf_random.best_estimator_
# Out:
# RandomForestRegressor(max_depth=81, min_samples_leaf=2, min_samples_split=15,
#                       n_estimators=400)

# %%
rf_random.best_score_
# Out:
# -285.9798009510813

# %%
rf_random.best_params_
# Out:
# {'n_estimators': 400,
#  'min_samples_split': 15,
#  'min_samples_leaf': 2,
#  'max_features': 'auto',
#  'max_depth': 81}

# %%
predictions= rf_random.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(predictions,y_test)
# Out:
# 242.0958538707996

# %%
np.sqrt(242)
# Out:
# 15.556349186104045

# %%
def features(data):
    c=np.array([data])
    aqi=int(rf_random.predict(c))
    return "Your AQI (avg. of past 24 hrs): {}".format(aqi)

# %%
data=[236,963,856,100,40,300,120]

# %%
features(data)
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# 'Your AQI (avg. of past 24 hrs): 251'

# %%
df.columns
# Out:
# Index(['PM2.5', 'PM10', 'NO2', 'NH3', 'SO2', 'CO', 'OZONE',
#        'AQI (avg. of past 24hrs) '],
#       dtype='object')

# %%
d= [86,145,76,1,19,1583,5]

# %%
features(d)
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# 'Your AQI (avg. of past 24 hrs): 148'

# %%
df.describe()
# Out:
#             PM2.5        PM10         NO2         NH3         SO2          CO  \
# count  366.000000  366.000000  366.000000  366.000000  366.000000  366.000000
# mean   184.049180  173.191257   61.513661    9.557377   16.390710   52.218579
# std    109.390981   88.671297   28.284728    2.692605    4.780992   14.364961
# min     24.000000   32.000000   24.000000    5.000000    7.000000   25.000000
# 25%     96.000000  107.250000   40.000000    8.000000   13.000000   43.000000
# 50%    159.500000  154.000000   53.000000    9.000000   16.000000   49.000000
# 75%    272.000000  217.000000   79.000000   11.000000   20.000000   60.000000
# max    455.000000  469.000000  146.000000   23.000000   33.000000  102.000000
#
#             OZONE  AQI (avg. of past 24hrs)
# count  366.000000                 366.000000
# mean    48.918033                 185.136612
# std     23.517498                 107.364303
# min     13.000000                  41.000000
# ...

# %%
df.columns
# Out:
# Index(['PM2.5', 'PM10', 'NO2', 'NH3', 'SO2', 'CO', 'OZONE',
#        'AQI (avg. of past 24hrs) '],
#       dtype='object')

# %%
corrmat["AQI (avg. of past 24hrs) "].sort_values(ascending=False)
# Out:
# AQI (avg. of past 24hrs)     1.000000
# PM2.5                        0.978072
# PM10                         0.959698
# NO2                          0.802867
# CO                           0.798535
# NH3                          0.763115
# SO2                          0.490488
# OZONE                        0.309616
# Name: AQI (avg. of past 24hrs) , dtype: float64

# %%
from sklearn.linear_model import LinearRegression
lr= LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
from sklearn import svm
svr= svm.SVR()

# %%
from sklearn.model_selection import GridSearchCV
parameters= {'kernel':('linear','rbf'),'C':[1,2,3,4,5,10,15,17,20]}
svr_grid= GridSearchCV(estimator=svr, param_grid=parameters, scoring='accuracy',cv=5 )

# %%
svr_grid.fit(X_train,y_train)
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\hp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\hp\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\hp\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "C:\Users\hp\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 211, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "C:\Users\hp\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 93, in _check_targets
# ...

# %%
svr_grid.best_estimator_
# Out:
# SVR(C=1, kernel='linear')

# %%
svr_grid.best_params_
# Out:
# {'C': 1, 'kernel': 'linear'}

# %%
svr_grid.best_score_
# Out:
# nan

# %%
pred_svr=svr_grid.predict(X_test)

# %%
mean_squared_error(pred_svr,y_test)
# Out:
# 331.8473586680529

# %%
np.sqrt(331)
# Out:
# 18.193405398660254

# %% [markdown]
# Out of Support Vector Machine and Random Forest Random Forest gives slightly better accuracy

# %%
rf_random
# Out:
# RandomizedSearchCV(cv=5, estimator=RandomForestRegressor(),
#                    param_distributions={'max_depth': [5, 24, 43, 62, 81, 100],
#                                         'max_features': ['auto', 'sqrt'],
#                                         'min_samples_leaf': [2, 5, 9, 12, 15,
#                                                              20],
#                                         'min_samples_split': [2, 5, 10, 15,
#                                                               100],
#                                         'n_estimators': [100, 200, 300, 400,
#                                                          500, 600, 700, 800,
#                                                          900, 1000, 1100,
#                                                          1200]},
#                    random_state=42, scoring='neg_mean_squared_error',
#                    verbose=2)

# %%
a=[100,250,14,155,369,21,40]

# %%
features(a)
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# 'Your AQI (avg. of past 24 hrs): 186'

# %%
int(25.63)
# Out:
# 25
